# %%
pip install tweepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/dist-packages (3.10.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.2.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2022.9.24)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)

# %%
import pandas as pd
import time
import tweepy
import numpy as np

# %%
def twitter_config():
    """
    Fungsi utilitas untuk mengkonfigurasi konsumsi file API Twitter dengan␣
    ,!kunci yang disediakan.
    """
    # Otentikasi dan akses menggunakan kunci:
    auth = tweepy.OAuthHandler("1gL84DYYvFuXzHHhGi8Chabm7","piLRoeP9Scpoi62ex9pKVso2ddQXcEZM0K3iNLEpdR99SY6QIx")
    auth.set_access_token("1572036271262011392-wMkVYaB1emY7rtncJWyUypYUWwQtcg","QmJLO0AgAbB38gEvH6TJDarxOSMvAMmFTWjyCWnYOjWG2")
    # Kembalikan akses ke API:
    api = tweepy.API(auth)
    try:
        api.verify_credentials()
        print("Authentication OK")
    except:
        print("Error during authentication")
    return api

# %%
# buat extractor object
extractor = twitter_config()
# Out:
# Authentication OK

# %%
tweets = extractor.user_timeline(screen_name="jiemiardian", count=100)
print("Tweets terambil: {}.\n".format(len(tweets)))
# Out:
# Tweets terambil: 100.

# %%
# Kita dapat membuat kerangka data sebagai berikut:
dataset = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# Kami membuat tampilan kerangka data:
display(dataset.head(50))
# Out:
#                                                Tweets
# 0             @ndreamon @nurinuriii @nagotejena Hmmmm
# 1               @ginaanin Terharu banget, makasih kak
# 2   RT @ginaanin: Di sela keruwetan dan hal-hal ya...
# 3   Penting untuk content creator punya “peer revi...
# 4   Bayangin aja kalo ada konten prank dari akun b...
# 5   Banyak korban tidak melapor, karena lingkungan...
# 6   Hampir setiap hari saya mendapatkan kasus KDRT...
# 7   Ikut berduka cita atas kejadian Kanjuruhan\n\n...
# 8   Banyak banget ditandain nya. Tengkyu udah baca...
# 9   Twit tadi merespon tulisan teman saya mbak Ann...
# 10  Pura-pura ga ada masalah, ga membuat masalahny...
# 11  Ada yang tidak bisa digantikan oleh obat\n\nCi...
# 12  Pengobatan (dari psikiater) tidak bisa mengkom...
# 13  @nagotejena Kalo ikut tapi ga mau subscribe bo...
# 14  RT @nagotejena: It’s finally here!\n\nMinggu m...
# 15  @AdjieSanPutro Mas, tapi aku ya ga bisa sabar ...
# 16  @uberfunk Iya, gapapa banget kalo cocoknya ema...
# 17  @ifazulfa_ Gimana sik\n\nKalo pagi katanya “ma...
# 18  @macchiatotatoes Bisa jadi ya. Persiapan kehid...
# 19  @uberfunk Bener juga ya. Pernikahan akan berir...
# 20  @ifazulfa_ 4. Atau orang memang tidak disiapka...
# 21  Atau bisa jadi juga angka perceraian adalah ma...
# 22  Karna beberapa kali saya menemukan orang yang ...
# 23  Sebenernya baca berita kaya gini tu saya mikir...
# 24  @ndreamon @AdjieSanPutro Woi mas Adjie cuma na...
# 25  @sulmoney 😂😂\n\nYour content must be coming fr...
# 26                                     @fitridl Rehan
# 27  @lupaudahmakan Introvert tidak menyebabkan log...
# 28  @via_maulida Bisa jadi tentang cemas, depresi ...
# 29  @adidiadi Nah persis. Sebagian mungkin terjadi...
# 30  @nagotejena Jadi lo bales chat lama tu gara ga...
# 31                Begitulah…. https://t.co/Y5tftRck9o
# 32                        @ezash Ngaco ini lagi mas 😂
# 33  @kata_atina @belindch Artinya begitu sulit lup...
# 34  @adidiadi Menjadi gelisah karna tidak bisa men...
# 35  @JetVeetlev @anggraeniditaaa No, ga tau lebih ...
# 36                                  @askDika KAGET 😂😂
# 37  @Hilmi_ak Mungkin waktunya konsul. Cuy @ndream...
# 38  Anjir udah berhari hari ini lagu ga ilang dari...
# 39   Begitu sulit lupakan Rehan\n\nApalagi Rehan baik
# 40                         @daechwita93_ Tepat sekali
# 41  Lebih penting berpikir akurat, berpikir adapti...
# 42  Tidak semua pikiran positif itu baik\n\nMisaln...
# 43                          @meowlynnd @bersxhka 😂😂😂😂
# 44  @anggitanjung Nah cakep. Marah boleh aja, tapi...
# 45  Perasaanmu valid, tapi bukan berarti tindakan ...
# 46           @zarryhendrik TEH TAWAR ANGET FOR LYFE!!
# 47  @meiralyfe Antara cold turkey, kita hilangkan ...
# 48  Problem nya di awal memakan gula banyak, rasan...
# 49  Gula yang terlalu banyak juga mengganggu seseo...

# %%
data = dataset

# %%
# ------ Case Folding --------
# gunakan fungsi Series.str.lower() pada Pandas
data['Tweets'] = data['Tweets'].str.lower()

print('Case Folding Result : \n')
print(data['Tweets'].head(5))
print('\n\n\n')
# Out:
# Case Folding Result :
#
# 0              @ndreamon @nurinuriii @nagotejena hmmmm
# 1                @ginaanin terharu banget, makasih kak
# 2    rt @ginaanin: di sela keruwetan dan hal-hal ya...
# 3    penting untuk content creator punya “peer revi...
# 4    bayangin aja kalo ada konten prank dari akun b...
# Name: Tweets, dtype: object

# %%
import nltk

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import string 
import re #regex library

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

# ------ Tokenizing ---------

def remove_tweet_special(text):
    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")
                
data['Tweets'] = data['Tweets'].apply(remove_tweet_special)

#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

data['Tweets'] = data['Tweets'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

data['Tweets'] = data['Tweets'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

data['Tweets'] = data['Tweets'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

data['Tweets'] = data['Tweets'].apply(remove_whitespace_multiple)

# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

data['Tweets'] = data['Tweets'].apply(remove_singl_char)

# NLTK word rokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

data['Text_tokens'] = data['Tweets'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(data['Text_tokens'].head())
print('\n\n\n')
# Out:
# Tokenizing Result :
#
# 0                                              [hmmmm]
# 1                      [terharu, banget, makasih, kak]
# 2    [rt, di, sela, keruwetan, dan, halhal, yang, k...
# 3    [penting, untuk, content, creator, punya, peer...
# 4    [bayangin, aja, kalo, ada, konten, prank, dari...
# Name: Text_tokens, dtype: object

# %%
# NLTK calc frequency distribution
def freqDist_wrapper(text):
    return FreqDist(text)

data['Text_tokens_fdist'] = data['Text_tokens'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(data['Text_tokens_fdist'].head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0                                         [(hmmmm, 1)]
# 1    [(terharu, 1), (banget, 1), (makasih, 1), (kak...
# 2    [(yang, 2), (rt, 1), (di, 1), (sela, 1), (keru...
# 3    [(penting, 1), (untuk, 1), (content, 1), (crea...
# 4    [(bayangin, 1), (aja, 1), (kalo, 1), (ada, 1),...
# Name: Text_tokens_fdist, dtype: object

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')

# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')


# ---------------------------- manualy add stopword  ------------------------------------
# append additional stopword
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah'])

# ---------------------------------------------------------------------------------------

# convert list to dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

data['Text_tokens_WSW'] = data['Text_tokens'].apply(stopwords_removal) 


print(data['Text_tokens_WSW'].head())
# Out:
# 0                                              [hmmmm]
# 1                      [terharu, banget, makasih, kak]
# 2    [keruwetan, halhal, kemrungsung, datanglah, se...
# 3    [content, creator, peer, review, bantu, batasa...
# 4    [bayangin, konten, prank, akun, berpengikut, k...
# Name: Text_tokens_WSW, dtype: object
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
data['Text_tokens_WSW']
# Out:
# 0                                               [hmmmm]
# 1                       [terharu, banget, makasih, kak]
# 2     [keruwetan, halhal, kemrungsung, datanglah, se...
# 3     [content, creator, peer, review, bantu, batasa...
# 4     [bayangin, konten, prank, akun, berpengikut, k...
#                             ...
# 95    [anggota, keluarga, kekerasan, perilaku, disem...
# 96    [terbaik, menjaga, nama, berkelakuan, orang, m...
# 97    [dosen, hidup, orang, terbentuknya, tahunan, k...
# 98    [mitos, temen, temen, pengobatan, dokter, memp...
# 99                   [yes, it, is, okay, terburu, buru]
# Name: Text_tokens_WSW, Length: 100, dtype: object

# %%
data.head()
# Out:
#                                               Tweets  \
# 0                                              hmmmm
# 1                         terharu banget makasih kak
# 2  rt di sela keruwetan dan halhal yang kemrungsu...
# 3  penting untuk content creator punya peer revie...
# 4  bayangin aja kalo ada konten prank dari akun b...
#
#                                          Text_tokens  \
# 0                                            [hmmmm]
# 1                    [terharu, banget, makasih, kak]
# 2  [rt, di, sela, keruwetan, dan, halhal, yang, k...
# 3  [penting, untuk, content, creator, punya, peer...
# 4  [bayangin, aja, kalo, ada, konten, prank, dari...
#
#                                    Text_tokens_fdist  \
# 0                                       {'hmmmm': 1}
# 1  {'terharu': 1, 'banget': 1, 'makasih': 1, 'kak...
# 2  {'rt': 1, 'di': 1, 'sela': 1, 'keruwetan': 1, ...
# 3  {'penting': 1, 'untuk': 1, 'content': 1, 'crea...
# 4  {'bayangin': 1, 'aja': 1, 'kalo': 1, 'ada': 1,...
#
#                                      Text_tokens_WSW
# 0                                            [hmmmm]
# 1                    [terharu, banget, makasih, kak]
# 2  [keruwetan, halhal, kemrungsung, datanglah, se...
# 3  [content, creator, peer, review, bantu, batasa...
# 4  [bayangin, konten, prank, akun, berpengikut, k...

# %%
# !pip install swifter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: swifter in /usr/local/lib/python3.7/dist-packages (1.3.4)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.7/dist-packages (from swifter) (5.9.2)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (7.7.1)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.3.5)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.5.0)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (2022.2.0)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (0.8.3)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (4.64.1)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.7/dist-packages (from swifter) (5.0.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (1.15.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2022.8.2)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (21.3)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.21.6)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (3.0.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (3.6.1)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (7.9.0)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.1.12)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.0.10)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.18.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (57.4.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->dask[dataframe]>=2.10.0->swifter) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2022.2.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.7/dist-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.3.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.13.3)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.4.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.6.1)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.11.3)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (23.2.1)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.6.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.16.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.18.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.12.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (22.1.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.8.1)

# %%
# !pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 5.1 MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# %%
# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in data['Text_tokens_WSW']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

data['Text_tokens_stemmed'] = data['Text_tokens_WSW'].swifter.apply(get_stemmed_term)
print(data['Text_tokens_stemmed'])
# Out:
# 481
# ------------------------
# hmmmm : hmmmm
# terharu : haru
# banget : banget
# makasih : makasih
# kak : kak
# keruwetan : ruwet
# halhal : halhal
# kemrungsung : kemrungsung
# datanglah : datang
# selingan : seling
# menghangatkan : hangat
# terluka : luka
# content : content
# creator : creator
# peer : peer
# review : review
# bantu : bantu
# batasan : batas
# kritik : kritik
# seb : seb
# bayangin : bayangin
# konten : konten
# prank : prank
# akun : akun
# berpengikut : ikut
# kebayang : bayang
# gimana : gimana
# pengaruhnya : pengaruh
# kepercaya : percaya
# korban : korban
# melapor : lapor
# lingkungan : lingkung
# nggak : nggak
# percaya : percaya
# kekerasan : keras
# pelaku : laku
# kdrt : kdrt
# poli : pol
# kesulitan : sulit
# pengalaman : alam
# berduka : duka
# cita : cita
# kejadian : jadi
# kanjuruhan : kanjuruhan
# semoga : moga
# keadilan : adil
# ditegakkan : tegak
# perbaikan : baik
# sistem : sistem
# menyel : sel
# ditandain : ditandain
# tengkyu : tengkyu
# udah : udah
# baca : baca
# jeruk : jeruk
# twit : twit
# merespon : merespon
# tulisan : tulis
# teman : teman
# mbak : mbak
# annisa : annisa
# mengutip : kutip
# kisah : kisah
# fia : fia
# trigger : trigger
# warning : warning
# purapura : purapura
# selesai : selesai
# tetangga : tetangga
# diabaikan : abai
# kekerasannya : keras
# sel : sel
# digantikan : ganti
# obat : obat
# cinta : cinta
# kasih : kasih
# sayang : sayang
# pertemuan : temu
# kedekatan : dekat
# perhatian : perhati
# telinga : telinga
# mendengar : dengar
# hati : hati
# terbuka : buka
# pengobatan : obat
# psikiater : psikiater
# mengkompensasi : kompensasi
# kurangnya : kurang
# us : us
# senate : senate
# hearing : hearing
# kalimat : kalimat
# subscribe : subscribe
# its : its
# finally : finally
# here : here
# minggu : minggu
# malem : malem
# nganggur : nganggur
# yuk : yuk
# gabung : gabung
# bahas : bahas
# quarter : quarter
# life : life
# crisis : crisis
# nanya : nanya
# sharing : sharing
# deng : deng
# mas : mas
# sabar : sabar
# dipikir : pikir
# sanggup : sanggup
# menurutku : turut
# iya : iya
# gapapa : gapapa
# cocoknya : cocok
# emang : emang
# sik : sik
# pagi : pagi
# sore : sore
# persiapan : siap
# kehidupan : hidup
# pernikahan : nikah
# sekedar : dar
# resepsi : resepsi
# bener : bener
# beriringan : iring
# problem : problem
# menikah : meni
# problemnya : problem
# orang : orang
# disiapkan : siap
# model : model
# berhubungan : hubung
# sehat : sehat
# langsung : langsung
# disuruh : suruh
# nikah : nikah
# angka : angka
# perceraian : cerai
# menemukan : temu
# resolusi : resolusi
# konflik : konflik
# hubungan : hubung
# wa : wa
# karna : karna
# kali : kali
# bercerai : cerai
# alasan : alas
# finansial : finansial
# tuntutan : tuntut
# keluarga : keluarga
# sebenernya : sebenernya
# berita : berita
# kaya : kaya
# gini : gin
# tu : tu
# mikir : mikir
# meningkatnya : tingkat
# woi : woi
# adjie : adjie
# mengasumsikan : asumsi
# memecah : pecah
# belah : belah
# menuduh : tuduh
# your : your
# must : must
# be : be
# coming : coming
# from : from
# trauma : trauma
# rehan : rehan
# introvert : introvert
# menyebabkan : sebab
# logical : logical
# fallacy : fallacy
# maulida : maulida
# cemas : cemas
# depresi : depresi
# gangguan : ganggu
# jiwa : jiwa
# kebiasaan : biasa
# persis : persis
# sebagiannya : bagi
# dapatkah : dapat
# melih : melih
# lo : lo
# bales : bales
# chat : chat
# gara : gara
# foto : foto
# oke : oke
# baiklah : baik
# ngaco : ngaco
# atina : atina
# sulit : sulit
# lupakan : lupa
# gelisah : gelisah
# mengusir : usir
# lagu : lagu
# pikiran : pikir
# no : no
# plis : plis
# kaget : kaget
# ak : ak
# konsul : konsul
# cuy : cuy
# gue : gue
# anjir : anjir
# berhari : hari
# ilang : ilang
# kepala : kepala
# berpikir : pikir
# akurat : akurat
# adaptif : adaptif
# seimbang : imbang
# ketimbang : ketimbang
# positif : positif
# reali : real
# kerjaannya : kerja
# mai : mai
# cakep : cakep
# marah : marah
# tindakan : tindak
# perasaanmu : asa
# valid : valid
# akibat : akibat
# perasaan : asa
# membenarkan : benar
# perilaku : perilaku
# teh : teh
# tawar : tawar
# anget : anget
# for : for
# lyfe : lyfe
# cold : cold
# turkey : turkey
# hilangkan : hilang
# nyaman : nyaman
# terukur : ukur
# ber : ber
# memakan : makan
# gula : gula
# energi : energi
# meningkat : tingkat
# mengganggu : ganggu
# menghadapi : hadap
# stres : stres
# stressor : stressor
# ditol : tol
# diet : diet
# meningkatkan : tingkat
# mood : mood
# pria : pria
# wanita : wanita
# penelitian : teliti
# mene : mene
# ngomongin : ngomongin
# minum : minum
# manismanis : manismanis
# minuman : minum
# manis : manis
# lho : lho
# ras : ras
# jantung : jantung
# pisang : pisang
# nek : nek
# pas : pas
# cilikanmu : cili
# dolanan : dolan
# atari : atar
# ojo : ojo
# sok : sok
# ora : ora
# mudeng : mudeng
# ngasi : ngasi
# kesempatan : sempat
# orangnya : orang
# ngulangin : ngulangin
# kesalahan : salah
# beda : beda
# cerita : cerita
# kalinya : kali
# kotaro : kotaro
# minami : mam
# layar : layar
# kaca : kaca
# dok : dok
# shadow : shadow
# organization : organization
# komentar : komentar
# dikirim : kirim
# gorgom : gorgom
# mengalahkan : kalah
# ko : ko
# kanan : kanan
# ngajarin : ngajarin
# jurus : jurus
# kungfu : kungfu
# berperan : peran
# kegagalan : gagal
# kesuksesan : sukses
# sukses : sukses
# respondent : respondent
# needed : needed
# klik : klik
# tautan : taut
# berpartisipasi : partisipasi
# partisipan : partisipan
# beruntung : untung
# manusia : manusia
# menjaga : jaga
# kenyamanan : nyaman
# ketenangan : tenang
# hidupnya : hidup
# situasi : situasi
# mengancam : ancam
# kondisi : kondisi
# hai : hai
# tertarik : tarik
# membantu : bantu
# layanan : layan
# kesehatan : sehat
# mental : mental
# indonesia : indonesia
# mari : mari
# bergabung : gabung
# esteem : esteem
# pro : pro
# salah : salah
# rumah : rumah
# tangga : tangga
# menganggap : anggap
# pasangannya : pasang
# capek : capek
# susah : susah
# seberat : berat
# apapun : apa
# jalanihidupmu : jalanihidupmu
# berharga : harga
# layak : layak
# bahagia : bahagia
# syarat : syarat
# cognitive : cognitive
# distortion : distortion
# namanya : nama
# rationalization : rationalization
# met : met
# ulang : ulang
# kakakkk : kakakkk
# ngetawain : ngetawain
# generasi : generasi
# strawberry : strawberry
# generation : generation
# pertanyaannya : tanya
# sediki : dik
# kerendahan : rendah
# kesadaran : sadar
# ketahui : tahu
# kesepakatan : sepakat
# mudah : mudah
# tai : tai
# kucing : kucing
# bu : bu
# password : password
# minimal : minimal
# memudahkan : mudah
# menjangk : menjangk
# tanda : tanda
# activating : activating
# strategy : strategy
# anxious : anxious
# attachment : attachment
# malas : malas
# meng : meng
# posesif : posesif
# mengecek : ecek
# pasangan : pasang
# live : live
# location : location
# curiga : curiga
# stalking : stalking
# media : media
# sosial : sosial
# pes : pes
# mastin : mastin
# anak : anak
# investasi : investasi
# tua : tua
# dana : dana
# darurat : darurat
# paylater : paylater
# hmm : hmm
# true : true
# so : so
# liv : liv
# postingan : postingan
# promosi : promosi
# tujuannya : tuju
# menghibur : hibur
# edukasi : edukasi
# nonton : nonton
# menunda : tunda
# stimulus : stimulus
# kebanyakan : banyak
# perl : perl
# dik : dik
# perempuan : perempuan
# menolak : tolak
# asertif : asertif
# berujung : ujung
# kematian : mati
# bebankan : beban
# komunika : komunika
# halo : halo
# melaporkan : lapor
# toko : toko
# menjual : jual
# buku : buku
# merawat : rawat
# luka : luka
# batin : batin
# bajakan : baja
# nayna : nayna
# jug : jug
# mendengarkan : dengar
# yes : yes
# memahami : paham
# bentuk : bentuk
# menghakimi : hakim
# shaaa : shaaa
# good : good
# ngerasa : ngerasa
# ngerti : ngerti
# menutup : tutup
# ruang : ruang
# dikenalin : dikenalin
# mbah : mbah
# dukun : dukun
# astaga : astaga
# rame : rame
# sasaran : sasar
# galau : galau
# mikirin : mikirin
# skripsi : skripsi
# sampe : sampe
# tesis : tesis
# nebak : nebak
# respon : respon
# lai : lai
# ngopi : ngopi
# nama : nama
# pasanganmu : pasang
# tidurnya : tidur
# kayang : kayang
# ngambil : ngambil
# baju : baju
# tumpukan : tumpu
# langs : langs
# anggota : anggota
# disembunyikan : sembunyi
# terbaik : baik
# berkelakuan : laku
# menyembunyikan : sembunyi
# kelakuan : laku
# dosen : dosen
# hidup : hidup
# terbentuknya : bentuk
# tahunan : tahun
# konseling : konseling
# mitos : mitos
# temen : temen
# dokter : dokter
# mempertimbangkan : timbang
# keamanan : aman
# dikembangkan : kembang
# it : it
# is : is
# okay : okay
# terburu : buru
# buru : buru
# {'hmmmm': 'hmmmm', 'terharu': 'haru', 'banget': 'banget', 'makasih': 'makasih', 'kak': 'kak', 'keruwetan': 'ruwet', 'halhal': 'halhal', 'kemrungsung': 'kemrungsung', 'datanglah': 'datang', 'selingan': 'seling', 'menghangatkan': 'hangat', 'terluka': 'luka', 'content': 'content', 'creator': 'creator', 'peer': 'peer', 'review': 'review', 'bantu': 'bantu', 'batasan': 'batas', 'kritik': 'kritik', 'seb': 'seb', 'bayangin': 'bayangin', 'konten': 'konten', 'prank': 'prank', 'akun': 'akun', 'berpengikut': 'ikut', 'kebayang': 'bayang', 'gimana': 'gimana', 'pengaruhnya': 'pengaruh', 'kepercaya': 'percaya', 'korban': 'korban', 'melapor': 'lapor', 'lingkungan': 'lingkung', 'nggak': 'nggak', 'percaya': 'percaya', 'kekerasan': 'keras', 'pelaku': 'laku', 'kdrt': 'kdrt', 'poli': 'pol', 'kesulitan': 'sulit', 'pengalaman': 'alam', 'berduka': 'duka', 'cita': 'cita', 'kejadian': 'jadi', 'kanjuruhan': 'kanjuruhan', 'semoga': 'moga', 'keadilan': 'adil', 'ditegakkan': 'tegak', 'perbaikan': 'baik', 'sistem': 'sistem', 'menyel': 'sel', 'ditandain': 'ditandain', 'tengkyu': 'tengkyu', 'udah': 'udah', 'baca': 'baca', 'jeruk': 'jeruk', 'twit': 'twit', 'merespon': 'merespon', 'tulisan': 'tulis', 'teman': 'teman', 'mbak': 'mbak', 'annisa': 'annisa', 'mengutip': 'kutip', 'kisah': 'kisah', 'fia': 'fia', 'trigger': 'trigger', 'warning': 'warning', 'purapura': 'purapura', 'selesai': 'selesai', 'tetangga': 'tetangga', 'diabaikan': 'abai', 'kekerasannya': 'keras', 'sel': 'sel', 'digantikan': 'ganti', 'obat': 'obat', 'cinta': 'cinta', 'kasih': 'kasih', 'sayang': 'sayang', 'pertemuan': 'temu', 'kedekatan': 'dekat', 'perhatian': 'perhati', 'telinga': 'telinga', 'mendengar': 'dengar', 'hati': 'hati', 'terbuka': 'buka', 'pengobatan': 'obat', 'psikiater': 'psikiater', 'mengkompensasi': 'kompensasi', 'kurangnya': 'kurang', 'us': 'us', 'senate': 'senate', 'hearing': 'hearing', 'kalimat': 'kalimat', 'subscribe': 'subscribe', 'its': 'its', 'finally': 'finally', 'here': 'here', 'minggu': 'minggu', 'malem': 'malem', 'nganggur': 'nganggur', 'yuk': 'yuk', 'gabung': 'gabung', 'bahas': 'bahas', 'quarter': 'quarter', 'life': 'life', 'crisis': 'crisis', 'nanya': 'nanya', 'sharing': 'sharing', 'deng': 'deng', 'mas': 'mas', 'sabar': 'sabar', 'dipikir': 'pikir', 'sanggup': 'sanggup', 'menurutku': 'turut', 'iya': 'iya', 'gapapa': 'gapapa', 'cocoknya': 'cocok', 'emang': 'emang', 'sik': 'sik', 'pagi': 'pagi', 'sore': 'sore', 'persiapan': 'siap', 'kehidupan': 'hidup', 'pernikahan': 'nikah', 'sekedar': 'dar', 'resepsi': 'resepsi', 'bener': 'bener', 'beriringan': 'iring', 'problem': 'problem', 'menikah': 'meni', 'problemnya': 'problem', 'orang': 'orang', 'disiapkan': 'siap', 'model': 'model', 'berhubungan': 'hubung', 'sehat': 'sehat', 'langsung': 'langsung', 'disuruh': 'suruh', 'nikah': 'nikah', 'angka': 'angka', 'perceraian': 'cerai', 'menemukan': 'temu', 'resolusi': 'resolusi', 'konflik': 'konflik', 'hubungan': 'hubung', 'wa': 'wa', 'karna': 'karna', 'kali': 'kali', 'bercerai': 'cerai', 'alasan': 'alas', 'finansial': 'finansial', 'tuntutan': 'tuntut', 'keluarga': 'keluarga', 'sebenernya': 'sebenernya', 'berita': 'berita', 'kaya': 'kaya', 'gini': 'gin', 'tu': 'tu', 'mikir': 'mikir', 'meningkatnya': 'tingkat', 'woi': 'woi', 'adjie': 'adjie', 'mengasumsikan': 'asumsi', 'memecah': 'pecah', 'belah': 'belah', 'menuduh': 'tuduh', 'your': 'your', 'must': 'must', 'be': 'be', 'coming': 'coming', 'from': 'from', 'trauma': 'trauma', 'rehan': 'rehan', 'introvert': 'introvert', 'menyebabkan': 'sebab', 'logical': 'logical', 'fallacy': 'fallacy', 'maulida': 'maulida', 'cemas': 'cemas', 'depresi': 'depresi', 'gangguan': 'ganggu', 'jiwa': 'jiwa', 'kebiasaan': 'biasa', 'persis': 'persis', 'sebagiannya': 'bagi', 'dapatkah': 'dapat', 'melih': 'melih', 'lo': 'lo', 'bales': 'bales', 'chat': 'chat', 'gara': 'gara', 'foto': 'foto', 'oke': 'oke', 'baiklah': 'baik', 'ngaco': 'ngaco', 'atina': 'atina', 'sulit': 'sulit', 'lupakan': 'lupa', 'gelisah': 'gelisah', 'mengusir': 'usir', 'lagu': 'lagu', 'pikiran': 'pikir',  ...
# ------------------------
# Pandas Apply:   0%|          | 0/100 [00:00<?, ?it/s]
# 0                                               [hmmmm]
# 1                          [haru, banget, makasih, kak]
# 2     [ruwet, halhal, kemrungsung, datang, seling, h...
# 3     [content, creator, peer, review, bantu, batas,...
# 4     [bayangin, konten, prank, akun, ikut, bayang, ...
#                             ...
# 95    [anggota, keluarga, keras, perilaku, sembunyi,...
# 96      [baik, jaga, nama, laku, orang, sembunyi, laku]
# 97    [dosen, hidup, orang, bentuk, tahun, konseling...
# 98    [mitos, temen, temen, obat, dokter, timbang, a...
# 99                      [yes, it, is, okay, buru, buru]
# Name: Text_tokens_stemmed, Length: 100, dtype: object

# %%
data.head()
# Out:
#                                               Tweets  \
# 0                                              hmmmm
# 1                         terharu banget makasih kak
# 2  rt di sela keruwetan dan halhal yang kemrungsu...
# 3  penting untuk content creator punya peer revie...
# 4  bayangin aja kalo ada konten prank dari akun b...
#
#                                          Text_tokens  \
# 0                                            [hmmmm]
# 1                    [terharu, banget, makasih, kak]
# 2  [rt, di, sela, keruwetan, dan, halhal, yang, k...
# 3  [penting, untuk, content, creator, punya, peer...
# 4  [bayangin, aja, kalo, ada, konten, prank, dari...
#
#                                    Text_tokens_fdist  \
# 0                                       {'hmmmm': 1}
# 1  {'terharu': 1, 'banget': 1, 'makasih': 1, 'kak...
# 2  {'rt': 1, 'di': 1, 'sela': 1, 'keruwetan': 1, ...
# 3  {'penting': 1, 'untuk': 1, 'content': 1, 'crea...
# 4  {'bayangin': 1, 'aja': 1, 'kalo': 1, 'ada': 1,...
#
#                                      Text_tokens_WSW  \
# 0                                            [hmmmm]
# 1                    [terharu, banget, makasih, kak]
# 2  [keruwetan, halhal, kemrungsung, datanglah, se...
# 3  [content, creator, peer, review, bantu, batasa...
# 4  [bayangin, konten, prank, akun, berpengikut, k...
#
#                                  Text_tokens_stemmed
# 0                                            [hmmmm]
# 1                       [haru, banget, makasih, kak]
# 2  [ruwet, halhal, kemrungsung, datang, seling, h...
# 3  [content, creator, peer, review, bantu, batas,...
# 4  [bayangin, konten, prank, akun, ikut, bayang, ...

# %%
data.head(30)
# Out:
#                                                Tweets  \
# 0                                               hmmmm
# 1                          terharu banget makasih kak
# 2   rt di sela keruwetan dan halhal yang kemrungsu...
# 3   penting untuk content creator punya peer revie...
# 4   bayangin aja kalo ada konten prank dari akun b...
# 5   banyak korban tidak melapor karena lingkungan ...
# 6   hampir setiap hari saya mendapatkan kasus kdrt...
# 7   ikut berduka cita atas kejadian kanjuruhan sem...
# 8   banyak banget ditandain nya tengkyu udah baca ...
# 9   twit tadi merespon tulisan teman saya mbak ann...
# 10  purapura ga ada masalah ga membuat masalahnya ...
# 11  ada yang tidak bisa digantikan oleh obat cinta...
# 12  pengobatan dari psikiater tidak bisa mengkompe...
# 13       kalo ikut tapi ga mau subscribe boleh ga kak
# 14  rt its finally here minggu malem nganggur yuk ...
# 15  mas tapi aku ya ga bisa sabar kalo satu hal in...
# 16      iya gapapa banget kalo cocoknya emang sendiri
# 17  gimana sik kalo pagi katanya masih pagi kalo s...
# 18  bisa jadi ya persiapan kehidupan setelah perni...
# 19  bener juga ya pernikahan akan beriringan denga...
# 20  atau orang memang tidak disiapkan diberi model...
# 21  atau bisa jadi juga angka perceraian adalah ma...
# 22  karna beberapa kali saya menemukan orang yang ...
# 23  sebenernya baca berita kaya gini tu saya mikir...
# 24  woi mas adjie cuma nanya kenapa anda mengasums...
# 25       your content must be coming from your trauma
# 26                                              rehan
# 27        introvert tidak menyebabkan logical fallacy
# 28  maulida bisa jadi tentang cemas depresi atau b...
# 29  nah persis sebagian mungkin terjadi sebagianny...
#
#                                           Text_tokens  \
# 0                                             [hmmmm]
# 1                     [terharu, banget, makasih, kak]
# 2   [rt, di, sela, keruwetan, dan, halhal, yang, k...
# 3   [penting, untuk, content, creator, punya, peer...
# 4   [bayangin, aja, kalo, ada, konten, prank, dari...
# 5   [banyak, korban, tidak, melapor, karena, lingk...
# 6   [hampir, setiap, hari, saya, mendapatkan, kasu...
# 7   [ikut, berduka, cita, atas, kejadian, kanjuruh...
# 8   [banyak, banget, ditandain, nya, tengkyu, udah...
# 9   [twit, tadi, merespon, tulisan, teman, saya, m...
# 10  [purapura, ga, ada, masalah, ga, membuat, masa...
# 11  [ada, yang, tidak, bisa, digantikan, oleh, oba...
# 12  [pengobatan, dari, psikiater, tidak, bisa, men...
# 13  [kalo, ikut, tapi, ga, mau, subscribe, boleh, ...
# 14  [rt, its, finally, here, minggu, malem, ngangg...
# 15  [mas, tapi, aku, ya, ga, bisa, sabar, kalo, sa...
# 16  [iya, gapapa, banget, kalo, cocoknya, emang, s...
# 17  [gimana, sik, kalo, pagi, katanya, masih, pagi...
# 18  [bisa, jadi, ya, persiapan, kehidupan, setelah...
# 19  [bener, juga, ya, pernikahan, akan, beriringan...
# 20  [atau, orang, memang, tidak, disiapkan, diberi...
# 21  [atau, bisa, jadi, juga, angka, perceraian, ad...
# 22  [karna, beberapa, kali, saya, menemukan, orang...
# 23  [sebenernya, baca, berita, kaya, gini, tu, say...
# 24  [woi, mas, adjie, cuma, nanya, kenapa, anda, m...
# 25  [your, content, must, be, coming, from, your, ...
# 26                                            [rehan]
# 27  [introvert, tidak, menyebabkan, logical, fallacy]
# 28  [maulida, bisa, jadi, tentang, cemas, depresi,...
# 29  [nah, persis, sebagian, mungkin, terjadi, seba...
#
#                                     Text_tokens_fdist  \
# 0                                        {'hmmmm': 1}
# 1   {'terharu': 1, 'banget': 1, 'makasih': 1, 'kak...
# 2   {'rt': 1, 'di': 1, 'sela': 1, 'keruwetan': 1, ...
# 3   {'penting': 1, 'untuk': 1, 'content': 1, 'crea...
# 4   {'bayangin': 1, 'aja': 1, 'kalo': 1, 'ada': 1,...
# 5   {'banyak': 1, 'korban': 2, 'tidak': 1, 'melapo...
# 6   {'hampir': 1, 'setiap': 1, 'hari': 1, 'saya': ...
# 7   {'ikut': 1, 'berduka': 1, 'cita': 1, 'atas': 1...
# 8   {'banyak': 1, 'banget': 1, 'ditandain': 1, 'ny...
# 9   {'twit': 1, 'tadi': 1, 'merespon': 1, 'tulisan...
# 10  {'purapura': 1, 'ga': 3, 'ada': 2, 'masalah': ...
# 11  {'ada': 1, 'yang': 3, 'tidak': 1, 'bisa': 1, '...
# 12  {'pengobatan': 1, 'dari': 1, 'psikiater': 1, '...
# 13  {'kalo': 1, 'ikut': 1, 'tapi': 1, 'ga': 2, 'ma...
# 14  {'rt': 1, 'its': 1, 'finally': 1, 'here': 1, '...
# 15  {'mas': 1, 'tapi': 1, 'aku': 1, 'ya': 1, 'ga':...
# 16  {'iya': 1, 'gapapa': 1, 'banget': 1, 'kalo': 1...
# 17  {'gimana': 1, 'sik': 1, 'kalo': 3, 'pagi': 2, ...
# 18  {'bisa': 1, 'jadi': 1, 'ya': 1, 'persiapan': 2...
# 19  {'bener': 1, 'juga': 1, 'ya': 1, 'pernikahan':...
# 20  {'atau': 1, 'orang': 1, 'memang': 1, 'tidak': ...
# 21  {'atau': 1, 'bisa': 1, 'jadi': 1, 'juga': 1, '...
# 22  {'karna': 2, 'beberapa': 1, 'kali': 1, 'saya':...
# 23  {'sebenernya': 1, 'baca': 1, 'berita': 1, 'kay...
# 24  {'woi': 1, 'mas': 1, 'adjie': 1, 'cuma': 1, 'n...
# 25  {'your': 2, 'content': 1, 'must': 1, 'be': 1, ...
# 26                                       {'rehan': 1}
# 27  {'introvert': 1, 'tidak': 1, 'menyebabkan': 1,...
# 28  {'maulida': 1, 'bisa': 2, 'jadi': 2, 'tentang'...
# 29  {'nah': 1, 'persis': 1, 'sebagian': 1, 'mungki...
#
#                                       Text_tokens_WSW  \
# 0                                             [hmmmm]
# 1                     [terharu, banget, makasih, kak]
# 2   [keruwetan, halhal, kemrungsung, datanglah, se...
# 3   [content, creator, peer, review, bantu, batasa...
# 4   [bayangin, konten, prank, akun, berpengikut, k...
# 5   [korban, melapor, lingkungan, nggak, percaya, ...
# 6         [kdrt, poli, korban, kesulitan, pengalaman]
# 7   [berduka, cita, kejadian, kanjuruhan, semoga, ...
# 8   [banget, ditandain, tengkyu, udah, baca, baca,...
# 9   [twit, merespon, tulisan, teman, mbak, annisa,...
# 10  [purapura, selesai, tetangga, kdrt, diabaikan,...
# 11  [digantikan, obat, cinta, kasih, sayang, perte...
# 12  [pengobatan, psikiater, mengkompensasi, kurang...
# 13                                   [subscribe, kak]
# 14  [its, finally, here, minggu, malem, nganggur, ...
# 15   [mas, sabar, dipikir, sabar, sanggup, menurutku]
# 16             [iya, gapapa, banget, cocoknya, emang]
# 17  [gimana, sik, pagi, pagi, sore, sore, malem, u...
# 18  [persiapan, kehidupan, pernikahan, sekedar, pe...
# 19  [bener, pernikahan, beriringan, problem, menik...
# 20  [orang, disiapkan, model, berhubungan, sehat, ...
# 21  [angka, perceraian, menemukan, resolusi, konfl...
# 22  [karna, kali, menemukan, orang, bercerai, karn...
# 23  [sebenernya, baca, berita, kaya, gini, tu, mik...
# 24  [woi, mas, adjie, nanya, mengasumsikan, memeca...
# 25  [your, content, must, be, coming, from, your, ...
# 26                                            [rehan]
# 27         [introvert, menyebabkan, logical, fallacy]
# 28  [maulida, cemas, depresi, gangguan, jiwa, seke...
# 29             [persis, sebagiannya, dapatkah, melih]
#
#                                   Text_tokens_stemmed
# 0                                             [hmmmm]
# 1                        [haru, banget, makasih, kak]
# 2   [ruwet, halhal, kemrungsung, datang, seling, h...
# 3   [content, creator, peer, review, bantu, batas,...
# 4   [bayangin, konten, prank, akun, ikut, bayang, ...
# 5   [korban, lapor, lingkung, nggak, percaya, korb...
# 6                    [kdrt, pol, korban, sulit, alam]
# 7   [duka, cita, jadi, kanjuruhan, moga, adil, teg...
# 8   [banget, ditandain, tengkyu, udah, baca, baca,...
# 9   [twit, merespon, tulis, teman, mbak, annisa, k...
# 10  [purapura, selesai, tetangga, kdrt, abai, kera...
# 11  [ganti, obat, cinta, kasih, sayang, temu, deka...
# 12  [obat, psikiater, kompensasi, kurang, kasih, s...
# 13                                   [subscribe, kak]
# 14  [its, finally, here, minggu, malem, nganggur, ...
# 15         [mas, sabar, pikir, sabar, sanggup, turut]
# 16                [iya, gapapa, banget, cocok, emang]
# 17  [gimana, sik, pagi, pagi, sore, sore, malem, u...
# 18           [siap, hidup, nikah, dar, siap, resepsi]
# 19  [bener, nikah, iring, problem, meni, problem, ...
# 20  [orang, siap, model, hubung, sehat, langsung, ...
# 21  [angka, cerai, temu, resolusi, konflik, hubung...
# 22  [karna, kali, temu, orang, cerai, karna, alas,...
# 23  [sebenernya, baca, berita, kaya, gin, tu, miki...
# 24  [woi, mas, adjie, nanya, asumsi, pecah, belah,...
# 25  [your, content, must, be, coming, from, your, ...
# 26                                            [rehan]
# 27               [introvert, sebab, logical, fallacy]
# 28  [maulida, cemas, depresi, ganggu, jiwa, dar, b...
# 29                       [persis, bagi, dapat, melih]

# %%
data['Tweets'].isnull().values.any()
# Out:
# False

# %%
##import data yang ada di drive sesuai dengan penamaan file
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks')

# %%
data.to_csv('/content/drive/My Drive/Colab Notebooks/data_NLP.csv',sep=';', index=False)

# %%
nlp = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data_NLP.csv',sep=';')

# %%
nlp
# Out:
#                                                Tweets  \
# 0                                               hmmmm
# 1                          terharu banget makasih kak
# 2   rt di sela keruwetan dan halhal yang kemrungsu...
# 3   penting untuk content creator punya peer revie...
# 4   bayangin aja kalo ada konten prank dari akun b...
# ..                                                ...
# 95  ada anggota keluarga melakukan kekerasan lalu ...
# 96  cara terbaik menjaga nama baik adalah dengan b...
# 97  rt dosen saya dulu pernah bilang masalah di hi...
# 98  ini mitos ya temen temen dalam memberikan peng...
# 99            yes it is okay tidak perlu terburu buru
#
#                                           Text_tokens  \
# 0                                           ['hmmmm']
# 1             ['terharu', 'banget', 'makasih', 'kak']
# 2   ['rt', 'di', 'sela', 'keruwetan', 'dan', 'halh...
# 3   ['penting', 'untuk', 'content', 'creator', 'pu...
# 4   ['bayangin', 'aja', 'kalo', 'ada', 'konten', '...
# ..                                                ...
# 95  ['ada', 'anggota', 'keluarga', 'melakukan', 'k...
# 96  ['cara', 'terbaik', 'menjaga', 'nama', 'baik',...
# 97  ['rt', 'dosen', 'saya', 'dulu', 'pernah', 'bil...
# 98  ['ini', 'mitos', 'ya', 'temen', 'temen', 'dala...
# 99  ['yes', 'it', 'is', 'okay', 'tidak', 'perlu', ...
#
#                              Text_tokens_fdist  \
# 0     <FreqDist with 1 samples and 1 outcomes>
# 1     <FreqDist with 4 samples and 4 outcomes>
# 2   <FreqDist with 17 samples and 18 outcomes>
# 3   <FreqDist with 17 samples and 17 outcomes>
# 4   <FreqDist with 17 samples and 17 outcomes>
# ..                                         ...
# 95  <FreqDist with 16 samples and 16 outcomes>
# 96  <FreqDist with 16 samples and 19 outcomes>
# 97  <FreqDist with 18 samples and 18 outcomes>
# 98  <FreqDist with 12 samples and 14 outcomes>
# 99    <FreqDist with 8 samples and 8 outcomes>
#
#                                       Text_tokens_WSW  \
# 0                                           ['hmmmm']
# 1             ['terharu', 'banget', 'makasih', 'kak']
# 2   ['keruwetan', 'halhal', 'kemrungsung', 'datang...
# 3   ['content', 'creator', 'peer', 'review', 'bant...
# 4   ['bayangin', 'konten', 'prank', 'akun', 'berpe...
# ..                                                ...
# 95  ['anggota', 'keluarga', 'kekerasan', 'perilaku...
# 96  ['terbaik', 'menjaga', 'nama', 'berkelakuan', ...
# 97  ['dosen', 'hidup', 'orang', 'terbentuknya', 't...
# 98  ['mitos', 'temen', 'temen', 'pengobatan', 'dok...
# 99     ['yes', 'it', 'is', 'okay', 'terburu', 'buru']
#
#                                   Text_tokens_stemmed
# 0                                           ['hmmmm']
# 1                ['haru', 'banget', 'makasih', 'kak']
# 2   ['ruwet', 'halhal', 'kemrungsung', 'datang', '...
# 3   ['content', 'creator', 'peer', 'review', 'bant...
# 4   ['bayangin', 'konten', 'prank', 'akun', 'ikut'...
# ..                                                ...
# 95  ['anggota', 'keluarga', 'keras', 'perilaku', '...
# 96  ['baik', 'jaga', 'nama', 'laku', 'orang', 'sem...
# 97  ['dosen', 'hidup', 'orang', 'bentuk', 'tahun',...
# 98  ['mitos', 'temen', 'temen', 'obat', 'dokter', ...
# 99        ['yes', 'it', 'is', 'okay', 'buru', 'buru']
#
# [100 rows x 5 columns]
